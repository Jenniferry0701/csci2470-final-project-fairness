# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("results/adult_fairness.csv")
df.groupby(["lr", "model"]).mean(numeric_only=True)
# Out:
#                  Unnamed: 0  accuracy  precision  recall     f1    spd  \
# lr    model
# 0.003 adversary         7.0     0.832      0.730   0.472  0.572 -0.116
#       improved          8.0     0.778      0.888   0.092  0.158 -0.034
#       vanilla           6.0     0.830      0.764   0.430  0.548 -0.116
#
#                  intersectional_spd  average_odds_difference  \
# lr    model
# 0.003 adversary               0.186                   -0.084
#       improved                0.044                   -0.054
#       vanilla                 0.182                   -0.116
#
#                  equal_opportunity_difference  differential_fairness  \
# lr    model
# 0.003 adversary                        -0.122                  1.936
#       improved                         -0.100                  3.498
#       vanilla                          -0.182                  2.402
#
#                  df_bias_amplification  fold  lambda_reg
# lr    model
# ...

# %%
df = pd.read_csv("results/compas_fairness.csv")
df.groupby(["lr", "model"]).mean(numeric_only=True)
# Out:
#                  Unnamed: 0  accuracy  precision  recall     f1    spd  \
# lr    model
# 0.003 adversary         7.0     0.678      0.674   0.556  0.612  0.000
#       improved          8.0     0.650      0.678   0.456  0.534  0.036
#       vanilla           6.0     0.672      0.660   0.566  0.606 -0.002
#
#                  intersectional_spd  average_odds_difference  \
# lr    model
# 0.003 adversary               0.172                    0.004
#       improved                0.508                    0.028
#       vanilla                 0.254                   -0.004
#
#                  equal_opportunity_difference  differential_fairness  \
# lr    model
# 0.003 adversary                         0.008                  0.496
#       improved                          0.004                  3.598
#       vanilla                          -0.002                  0.736
#
#                  df_bias_amplification  fold  lambda_reg
# lr    model
# ...
